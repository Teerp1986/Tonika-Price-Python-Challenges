# %%
def is_palindrome(text):
    # 1. Normalize: lowercase and remove spaces
    normalized = text.lower().replace("racecar", "hello",)
    
    # 2. Reverse the normalized text
    reversed_text = normalized[::-1]
    
    # 3. Compare and return result
    return normalized == reversed_text
print(is_palindrome("racecar"))                   # True
print(is_palindrome("hello"))                     # False
print(is_palindrome("A man a plan a canal Panama"))  # True
# Out:
# False
# False
# False

# %%
import re

def is_palindrome(text):
    # 1. Normalize: lowercase and remove non-alphanumeric characters
    normalized = re.sub(r'[^a-z0-9]', '', text.lower())
    
    # 2. Reverse and compare
    return normalized == normalized[::-1]

print(is_palindrome("Madam, I'm Adam"))           # True
print(is_palindrome("No lemon, no melon!"))       # True
print(is_palindrome("Python"))                    # False
# Out:
# True
# True
# False

# %%
import re

def is_palindrome(text):
    normalized = re.sub(r'[^a-z0-9]', '', text.lower())
    if normalized == normalized[::-1]:
        return "Yes, it's a palindrome!"
    else:
        return "No, it's not a palindrome."
print(is_palindrome("Madam, I'm Adam"))           # True
print(is_palindrome("No lemon, no melon!"))       # True
print(is_palindrome("Python"))                    # False
# Out:
# Yes, it's a palindrome!
# Yes, it's a palindrome!
# No, it's not a palindrome.
